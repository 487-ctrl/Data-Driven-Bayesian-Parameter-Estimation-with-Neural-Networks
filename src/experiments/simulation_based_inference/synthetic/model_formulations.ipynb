# %% [markdown]
# # Question: What influence has the choice of other simulator formulations on the resulting posterior distribution?
#
# - 'Explain the experimental details'
# - 'Introduce the experimental Variables'
# - 'Run the experiment'
# - 'discuss the results, and provide additional model measurements'
