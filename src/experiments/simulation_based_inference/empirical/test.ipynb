# %%
# Add the parent directory to the Python path, this allows us to import modules from there
import sys
sys.path.insert(0, '../../..')

from dataloader.dataloader import fetch_dataset, read_csv, _get_dataset_options
from analysis.plot_analysis import plot_frequency_data

# %%
_get_dataset_options()
# Out:
# ['DE_KA01',
#  'DE_OL01',
#  'EE01',
#  'ES_GC01',
#  'ES_GC02',
#  'ES_PM01',
#  'ES_PM02',
#  'ES_PM03',
#  'FO01',
#  'FR01',
#  'GB01',
#  'GB02',
#  'HR01',
#  'IS01',
#  'IT01',
#  'PL01',
#  'PT01',
#  'PT_LI01',
#  'RU01',
#  'SE01',
#  'sync01',
#  'TUR_IS01',
#  'US_TX01',
#  'US_TX02',
#  'US_UT',
#  'ZA01']

# %%
fetch_dataset("DE_KA01")
# Out:
# Data downloaded and saved as frequency_data\DE_KA01.csv

# %%
time, frequency_data = read_csv("frequency_data/DE_KA01.csv")

# %%
plot_frequency_data(time, frequency_data, "DE_KA01")
