# %% [markdown]
# # Conducting Experiments with Simulations of Various Mathematical Equations
#
# Currently implemented Simulators:
#
# - [Linear Equation](#linear-equation)
# - [Quadratic Equation](#quadratic-equation)
# - [Exponential Equation](#exponential-equation)
# - [Aggregated Swing Equation](#swing-equation)

# %% [markdown]
# ``Import nessecary modules and libraries, as well as asserting compatibility``

# %%
# Add the parent directory to the Python path, this allows us to import modules from there
import sys
sys.path.insert(0, '../../..')

import torch
from IPython.display import Image

from simulator.simulator_functions import swing_equation, linear_equation, quadratic_equation, exponential_equation
from analysis.plot_analysis import simulation_plot_animation

# %% [markdown]
# # LINEAR-EQUATION <https://en.wikipedia.org/wiki/Linear_equation>
#
# This equation models $ax + b = 0$ over a time period.
#
# ```for more depth look at the documentation provided```

# %%
# Define parameters for the simulator
theta = torch.tensor([0.2, 0.2])

# %%
# Simulate and plot the simulation
simulation_plot_animation(linear_equation, theta, 'linear_equation')

# %%
# Display the plotted simulation
display(Image(data=open('../../../figure_out/gif/simulation_linear_equation.gif','rb').read(), format='gif'))

# %% [markdown]
# # QUADRATIC-EQUATION <https://en.wikipedia.org/wiki/Quadratic_equation>
#
# This equation models $y = ax^2 + bx + c$ over a time period.
#
# ```for more depth look at the documentation provided```

# %%
# Define parameters for the simulator
theta = torch.tensor([0.2, 0.2, 0.2])

# %%
# Simulate and plot the simulation
simulation_plot_animation(quadratic_equation, theta, 'quadratic_equation')

# %%
# Display the plotted simulation
display(Image(data=open('../../../figure_out/gif/simulation_quadratic_equation.gif','rb').read(), format='gif'))

# %% [markdown]
# # EXPONENTIAL-EQUATION <https://en.wikipedia.org/wiki/Exponential_function>
#
# This equation models $y = a * b^x$ over a time period.
#
# ```for more depth look at the documentation provided```

# %%
# Define parameters for the simulator
theta = torch.tensor([0.2, 0.2])

# %%
# Simulate and plot the simulation
simulation_plot_animation(exponential_equation, theta, 'exponential_equation')

# %%
# Display the plotted simulation
display(Image(data=open('../../../figure_out/gif/simulation_exponential_equation.gif','rb').read(), format='gif'))

# %% [markdown]
# # SWING-EQUATION <https://en.wikipedia.org/wiki/Swing_equation>
#
# This equation is an implementation of the aggregated swing equation, modeling the dynamics of power system generators.
#
# ```for more depth look at the documentation provided```

# %%
# Define parameters for the simulator
theta = torch.tensor([0.2, 0.2, 0.2, 0.2])

# %%
# Simulate and plot the simulation
simulation_plot_animation(swing_equation, theta, 'swing_equation')

# %%
# Display the plotted simulation
display(Image(data=open('../../../figure_out/gif/simulation_swing_equation.gif','rb').read(), format='gif'))
